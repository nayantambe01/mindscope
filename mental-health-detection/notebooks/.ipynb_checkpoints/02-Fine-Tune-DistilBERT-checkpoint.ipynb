# %%
import pandas as pd
import re
import csv
from sklearn.model_selection import train_test_split
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
import torch
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import os

# --- 1. Load and Prepare the Dataset ---
print("Loading and preparing dataset...")

try:
    # Use all parameters to robustly load the messy CSV file
    df_full = pd.read_csv(
        '../data/reddit_posts.csv',
        encoding='latin-1',
        engine='python',
        quoting=csv.QUOTE_NONE,
        on_bad_lines='skip'
    )
    # Select only the two columns we need and rename 'class'
    df = df_full[['text', 'class']].rename(columns={'class': 'label_text'})
    
    # Convert text labels to numerical labels (1 for risk, 0 for no risk)
    df['label'] = df['label_text'].apply(lambda x: 1 if x == 'suicide' else 0)

    # We only need the text and the final numerical label
    df = df[['text', 'label']]
    
    # CRITICAL FIX: Ensure all entries in the 'text' column are strings
    df['text'] = df['text'].astype(str)
    
    # Remove any rows where the text might be empty after cleaning
    df = df[df['text'].str.strip().astype(bool)]
    
    print(f"Dataset loaded and prepared with {len(df)} rows.")

except Exception as e:
    print(f"An error occurred during data loading: {e}")
    df = pd.DataFrame({'text': [], 'label': []}) # Create empty df on error


# --- 2. Convert to Hugging Face Dataset ---
if not df.empty:
    # Split the data into training and validation sets
    train_df, val_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

    train_dataset = Dataset.from_pandas(train_df)
    val_dataset = Dataset.from_pandas(val_df)
    print("Converted to Hugging Face Dataset format.")
else:
    print("DataFrame is empty, skipping training.")


# --- 3. Load Tokenizer and Tokenize Data ---
MODEL_NAME = 'distilbert-base-uncased'

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def tokenize_function(examples):
    # Correctly pass the list of texts for batched processing
    return tokenizer(examples['text'], padding="max_length", truncation=True)

train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)

print("Tokenization complete.")


# --- 4. Load the Pre-trained Model ---
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)
print("DistilBERT model loaded.")


# --- 5. Set Up the Trainer ---
MODEL_OUTPUT_DIR = '../models/distilbert-finetuned-mental-health'

def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=1)
    # Use the correct function name: precision_recall_fscore_support
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='binary')
    acc = accuracy_score(p.label_ids, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

training_args = TrainingArguments(
    output_dir=MODEL_OUTPUT_DIR,
    num_train_epochs=1,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    eval_strategy="epoch"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)


# --- 6. Train the Model ---
print("\nStarting to fine-tune the model... (This will take a significant amount of time)")
trainer.train()
print("Model fine-tuning complete.")


# --- 7. Save the Final Model and Tokenizer ---
trainer.save_model(MODEL_OUTPUT_DIR)
tokenizer.save_pretrained(MODEL_OUTPUT_DIR)
print(f"✅ Improved model and tokenizer saved to {MODEL_OUTPUT_DIR}")
# Out:
# Loading and preparing dataset...
# Dataset loaded and prepared with 1072 rows.
# Converted to Hugging Face Dataset format.
# ...
# Map:   0%|          | 0/215 [00:00<?, ? examples/s]
# Tokenization complete.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBERT model loaded.
# --------------------------------------------------------------
# ImportError                  Traceback (most recent call last)
# Cell In[10], line 93
#      85     acc = accuracy_score(p.label_ids, preds)
#      86     return {
#      87         'accuracy': acc,
#      88         'f1': f1,
#      89         'precision': precision,
#      90         'recall': recall
#      91     }
# ...
